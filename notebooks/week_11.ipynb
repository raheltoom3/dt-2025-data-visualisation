# %%
number=3+7;
print("The total is", +number) #only comma because it's a number
# Out:
# The total is 10

# %%
pip install wordcloud
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 539.2/539.2 kB 2.2 MB/s eta 0:00:00
# ...
#   WARNING: The script wordcloud_cli is installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
name= "Rahel" #if it's a string we need to write inside the double quotes
print("Hello " +name)
# Out:
# Hello Rahel

# %%
for no in range(5):
    print(no)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for letter in name:
    print(letter)
    # "Rahel" is inside the double quotes. Python automatically understands this as a string (text).
    # strings in python are iteratable
# Out:
# R
# a
# h
# e
# l

# %%
age = 23

if age <=7: print("You can ride for free!");

else: print("Buy a ticket")

if age <18: print("Buy the child ticket");

else: print("Full ticket");
# Out:
# Buy a ticket
# Full ticket

# %%
sentence = "lumionmaas"
print("Print first 4 letters:", sentence[0:4]) #start: end
print(sentence[:3])

# extract letters from 5-9
print("Print letters 5-9:", sentence[4:9])
# extract letters from 5th to end 
print(sentence[5:])
# extract the last character 
print(sentence[-1])
# extract last four characters 
print(sentence[-4:])
#extract first letter of the substring starting from 5
print(sentence[5:][0])
#sentence[5:] - this will extract a substring starting from 5
#[0] - this will take the first character of that substring

#extract first 5 letters of the substring starting from 5
print(sentence[5:][0:5])

print(sentence[:]) #extract entire string

#extract every second character
print(sentence[::2])
# Out:
# Print first 4 letters: lumi
# lum
# Print letters 5-9: onmaa
# nmaas
# s
# maas
# n
# nmaas
# lumionmaas
# lmoma

# %%
sentence = "Alice went to the park and saw a beautiful bird singing"

words = sentence.split(" ") #split the sentence to words by spaces

print(words)

#extract first word
print(words[0])

#extract the first three words
print(words[0:3])

#extract the last three words
print(words[-3:])

#print number of words
print("The number of words: ", len(words))
# Out:
# ['Alice', 'went', 'to', 'the', 'park', 'and', 'saw', 'a', 'beautiful', 'bird', 'singing']
# Alice
# ['Alice', 'went', 'to']
# ['beautiful', 'bird', 'singing']
# The number of words:  11

# %%
from wordcloud import WordCloud

wc = WordCloud().generate("rain brings hope hope tere tore hei juhuu")

img =wc.to_image()
img.show()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
import urllib.request #this one we use to work with URLs

text = urllib.request.urlopen("https://raw.githubusercontent.com/raheltoom3/dt-2025-data-visualisation/refs/heads/codespace-jubilant-orbit-gr97595599x39g76/notebooks/poem.txt").read().decode("utf-8")

text[0:50]

WordCloud().generate_from_text(text).to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
WordCloud(stopwords=["and", "then", "but", "the", "of", "on", "to", "in", "from", "with"], background_color="white").generate_from_text(text).to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
import numpy as np # in order to 
from PIL import Image # import image class from PIL


img =urllib.request.urlretrieve("https://drive.google.com/uc?export=download&id=15nhewGg2fZD76ykGMvRnuA18U6BWs2Gq",
    "image1.png")

text = urllib.request.urlopen("https://drive.google.com/uc?export=download&id=10lBiT2yJWi5UsS1bUjWr4cq76PjS3PU0").read().decode("utf-8")

WordCloud().generate_from_text(text).to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>
